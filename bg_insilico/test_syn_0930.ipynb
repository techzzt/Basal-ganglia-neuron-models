# %% [markdown]
# ### Construct simulation network

# %%
### import packages 
from brian2 import *
from brian2.units import *
from brian2 import ms
from brian2tools import *
import matplotlib.pyplot as plt
import random
import numpy as np
import json

from simulation_runner import plot_results, run_simulation, load_params

# %%
### STN (I = 15)
json_file = './params_ref/STN_1.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)
# Out:
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_2vt54f1f/flag_test.o -w
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ai_neowd/flag_test.o -O3
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_ccl_pb9e/flag_test.o -ffast-math
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test__1pyc560/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_0ayc3e5k/flag_test.o -march=native
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_kiv68k2b/flag_test.o -std=c++11

# %%
### STN (LIF)
json_file = './params_ref/STN_2.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)
# Out:
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zvqq8_ul/flag_test.o -w
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_mzt_atj8/flag_test.o -O3
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_pvx1y165/flag_test.o -ffast-math
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_z_uc7q32/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_6352_a7j/flag_test.o -march=native
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_baf2p64a/flag_test.o -std=c++11

# %%
### STN
json_file = './params_ref/STN_3.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)

# %% [markdown]
# ### Synapse Connection

# %%
### Spontaneuous result without I
from simulation_runner_syn import plot_results_pre_post, plot_results_with_weight_matrix, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_without_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
# plot_results_with_weight_matrix(results, N_GPe, N_STN)
plot_raster(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 N_GPe = 30
#      15 N_STN = 30
# ---> 17 results = run_simulation_without_input(
#      18     N_GPe,
#      19     N_STN,
#      20     gpe_params_file,
#      21     stn_params_file,
#      22     synapse_params,
#      23     'GPe',
#      24     'STN',
#      25     "GPe_STN"
#      26 )
#      28 plot_results_pre_post(results)
#      29 # plot_results_with_weight_matrix(results, N_GPe, N_STN)
#
# NameError: name 'run_simulation_without_input' is not defined

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/brain/lib/python3.11/site-packages (from plotly) (24.0)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 4.8 MB/s eta 0:00:0000:0100:01
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.24.1 tenacity-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
### Spontaneuous result with current I (200ms ~ 500ms)
from simulation_runner_syn import run_simulation_with_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.07s). [brian2.stateupdaters.base.method_choice]

# %%
### adjust gap between vt, vr
from simulation_runner_syn import run_simulation_with_input, plot_results_pre_post, plot_raster
from brian2 import * 

gpe_params_file = './params_ref/GPe_T1_1_temp.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.08s). [brian2.stateupdaters.base.method_choice]

# %%
### Spontaneuous result with current I (ref 3)
from simulation_runner_syn import run_simulation_with_input, plot_results_pre_post, plot_raster
from brian2 import * 

gpe_params_file = './params_ref/GPe_T1_3.json'
stn_params_file = './params_ref/STN_3.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)

# %%
from simulation_runner_syn import plot_connectivity
plot_connectivity(results['synapse'], N_GPe, N_STN, title='GPe to STN Synaptic Connectivity')

# %% [markdown]
# ### Striatum - GPe - STN inhibitory (GABA)

# %%
### Result with inh/ext input with only one neuron 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'
striatum_params_file = './params_ref/MSN_D2_1.json'  # 추가: Striatum 파라미터 파일

synapse_params = {
    # STN - GPe (ext)
    'g0_n': 0.08*nS,
    'nmda_tau_syn': 100*ms,  
    'nmda_E_rev': 0*mV,
    'g0_a': 0.35*nS,
    'ampa_tau_syn': 12*ms,  
    'ampa_E_rev': 0*mV,
    
    # EXT - GPe
    'g0_g': 0.04*nS,
    'gaba_tau_syn': 87 * ms,
    'gaba_E_rev': -74* mV,
    
    # Cortex - EXT
    'cs_g0_n': 0.11 * nS,
    'cs_g0_a': 0.5 * nS,
    'cs_ampa_tau_syn': 12 * ms,
    'cs_nmda_tau_syn': 160 * ms,
    'cs_ampa_E_rev': 0 * mV,
    'cs_nmda_E_rev': 0 * mV,
    
    # Cortex - STN (excitatory connection)
    'csn_g0_n': 0.00625 * nS,
    'csn_g0_a': 0.25 * nS,
    'csn_ampa_tau_syn': 4 * ms,
    'csn_nmda_tau_syn': 160 * ms,
    'csn_ampa_E_rev': 0 * mV,
    'csn_nmda_E_rev': 0 * mV,
    
    # GPe - STN
    'gsn_g0_g': 0.08*nS,
    'gsn_gaba_tau_syn': 8 * ms,
    'gsn_gaba_E_rev': -84 * mV
}

N_GPe = 30
N_STN = 30
N_Striatum = 10

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    N_Striatum,
    gpe_params_file,
    stn_params_file,
    striatum_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    'Striatum',
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# WARNING    Model equations use the "unless refractory" flag but no refractory keyword was given. [brian2.groups.neurongroup.no_refractory]
# WARNING    Model equations use the "unless refractory" flag but no refractory keyword was given. [brian2.groups.neurongroup.no_refractory]
# WARNING    Model equations use the "unless refractory" flag but no refractory keyword was given. [brian2.groups.neurongroup.no_refractory]
# WARNING    'rates' is an internal variable of group 'poissongroup_1', but also exists in the run namespace with the value <Function>. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# Synapses(clock=Clock(dt=100. * usecond, name='defaultclock'), when=start, order=0, name='synapses_3')

# %%
### Result with inh/ext input with only one neuron 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'
striatum_params_file = './params_ref/MSN_D2_1.json'  # 추가: Striatum 파라미터 파일

synapse_params = {
    # GPe - STN (inhibit)
    'g0': 0.08*nS,
    'ampa_tau_syn': 8*ms,  # ampa (Hanson & Dieter Jaeger 2002)
    'ampa_E_rev': -84*mV,

    # EXT - STR
    'striatum_g0': 0.019 * nS,
    'striatum_ampa_E_rev': 0 * mV,
    'striatum_ampa_tau_syn': 160 * ms,
    
    # Cortex - STN (excitatory connection)
    'cortex_stn_g0': 0.00625 * nS,
    'cortex_stn_ampa_E_rev': 0 * mV,
    'cortex_stn_ampa_tau_syn': 160 * ms
}

N_GPe = 30
N_STN = 30
N_Striatum = 10

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    N_Striatum,
    gpe_params_file,
    stn_params_file,
    striatum_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    'Striatum',
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)

# %%
### Result with inh/ext input 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster

gpe_params_file = './params_ref/GPe_T1_3.json' 
stn_params_file = './params_ref/STN_3.json'

synapse_params = {
    # EXT - GPe
    'striatum_g0': 0.5 * nS,
    'striatum_ampa_E_rev': 0 * mV,
    'striatum_ampa_tau_syn': 5 * ms,

    # GPe - STN
    'g0': 1*nS,
    'ampa_tau_syn': 8*ms,  # ampa (Hanson & Dieter Jaeger 2002)
    'ampa_E_rev': -84*mV
  
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses_1', using method 'exact' (took 0.07s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.01s). [brian2.stateupdaters.base.method_choice]

# %%
### Visualization connection 
from simulation_runner_syn import plot_neuron_connections_3D
import numpy as np

# Example neuron positions (random)
neuron_positions = np.random.rand(10, 3) * 100  # 10 neurons in 3D space

# Example connections (random pairs of neurons)
connections = [(i, (i+1) % 10) for i in range(10)]  # Create circular connections

# Call the plotting function
plot_neuron_connections_3D(neuron_positions, connections)

# %% [markdown]
# - STDP: normal vs dopamine
# - https://brian2.readthedocs.io/en/stable/examples/frompapers.Izhikevich_2007.html
#
# - AdEX parameter list
# - https://brian2.readthedocs.io/en/stable/examples/frompapers.Naud_et_al_2008_adex_firing_patterns.html
# - delay 파라미터: 논문3 table1 참고
