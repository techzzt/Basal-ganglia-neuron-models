# %%
-64.4*(1+0.8*(-0.078))
# Out:
# -60.381440000000005

# %%
-64.4*(1+(-0.2)*(-0.078))
# Out:
# -65.40464000000001

# %%
# gpet1 el
-55.1*(1+(0.8)*(-0.181))
# Out:
# -47.12152

# %%
-55.1*(1+(-0.2)*(-0.181))
# Out:
# -57.09462

# %%
# msnd1 vr
-78.2*(1+(0.8)*(0.0296))
# Out:
# -80.051776

# %%
-78.2*(1+(-0.2)*(0.0296))
# Out:
# -77.737056

# %%
# msnd1 d
66.9*(1+(0.8)*(-0.45))
# Out:
# 42.815999999999995

# %%
66.9*(1+(-0.2)*(-0.45))
# Out:
# 72.921
