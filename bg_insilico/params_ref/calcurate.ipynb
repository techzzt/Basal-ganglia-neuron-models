# %%
-64.4*(1+(-0.8)*(-0.078))
# Out:
# -68.41856000000001

# %%
-64.4*(1+(0.2)*(-0.078))
# Out:
# -63.39536000000001

# %%
# gpet1 el
-55.1*(1+(-0.8)*(-0.181))
# Out:
# -63.078480000000006

# %%
-55.1*(1+(0.2)*(-0.181))
# Out:
# -53.105380000000004

# %%
# msnd1 vr
-78.2*(1+(-0.8)*(0.0296))
# Out:
# -76.348224

# %%
-78.2*(1+(0.2)*(0.0296))
# Out:
# -78.662944

# %%
# msnd1 d
66.9*(1+(-0.8)*(-0.45))
# Out:
# 90.98400000000001

# %%
66.9*(1+(0.2)*(-0.45))
# Out:
# 60.879000000000005

# %%
# FSN (normal)
1 + (-1.27)*(0.2)
# Out:
# 0.746

# %%
1 + (-1.27)*(-0.8)
# Out:
# 2.016

# %%
1 + (-0.53)*(0.2)
# Out:
# 0.894

# %%
1 + (-0.53)*(-0.8)
# Out:
# 1.424

# %%
1 + (-0.83)*(0.2)
# Out:
# 0.834

# %%
1 + (-0.83)*(-0.8)
# Out:
# 1.6640000000000001

# %%
# ctx-msnd1

1 + (1.04)*(0.2)
# Out:
# 1.208

# %%
1 + (1.04)*(-0.8)
# Out:
# 0.16799999999999993

# %%
1 + (-0.26)*(0.2)
# Out:
# 0.948

# %%
1 + (-0.26)*(-0.8)
# Out:
# 1.208

# %%
1 + (-0.9)*(0.2)
# Out:
# 0.82

# %%
1 + (-0.9)*(-0.8)
# Out:
# 1.7200000000000002

# %%
1 + (0.88)*(0.2)
# Out:
# 1.176

# %%
1 + (0.88)*(-0.8)
# Out:
# 0.29599999999999993

# %%
1 + (-1.22)*(0.2)
# Out:
# 0.756

# %%
1 + (-1.22)*(-0.8)
# Out:
# 1.976

# %%
# gpe

1+(-0.45)*(0.2)
# Out:
# 0.91

# %%
1+(-0.45)*(-0.8)

# %%
# stn 
1-(-0.45)*(0.2)
# Out:
# 1.09

# %%
1-(-0.45)*(-0.8)
# Out:
# 0.6399999999999999

# %%
1-(-0.24)*(0.2)
# Out:
# 1.048

# %%
1-(-0.24)*(-0.8)
# Out:
# 0.808

# %%
# msn 
# nmda
1+(1.04)*(-0.8)
# Out:
# 0.16799999999999993

# %%
1+(1.04)*(0.2)
# Out:
# 1.208

# %%
1+(-0.9)*(-0.8)
# Out:
# 1.7200000000000002

# %%
1+(-0.9)*(0.2)
# Out:
# 0.82

# %%
1+(0.88)*(0.2)
# Out:
# 1.176

# %%
# ctx - msnd1

1+(1.04)*(-0.8)
# Out:
# 0.16799999999999993

# %%
1+(1.04)*(0.2)
# Out:
# 1.208

# %%
# fsn msnd2 N

1+(-0.9)*(0.2)
# Out:
# 0.82

# %%
1+(-0.9)*(-0.8)
# Out:
# 1.7200000000000002

# %%
# p value calculate

# %%
500 / 37971
# Out:
# 0.013167943957230518

# %%
11/1599
# Out:
# 0.0068792995622263915

# %%
5/329
# Out:
# 0.015197568389057751

# %%
30/988
# Out:
# 0.030364372469635626

# %%
988/80000
# Out:
# 0.01235

# %%
329/80000
# Out:
# 0.0041125

# %%
364 * 1.176
# Out:
# 428.06399999999996

# %%
428 / 37971
# Out:
# 0.011271760027389324

# %%
(364 / 37971) * 1.76
# Out:
# 0.016871823233520315
