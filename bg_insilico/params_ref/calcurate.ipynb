# %%
-64.4*(1+(-0.8)*(-0.078))
# Out:
# -68.41856000000001

# %%
-64.4*(1+(0.2)*(-0.078))
# Out:
# -63.39536000000001

# %%
# gpet1 el
-55.1*(1+(-0.8)*(-0.181))
# Out:
# -63.078480000000006

# %%
-55.1*(1+(0.2)*(-0.181))
# Out:
# -53.105380000000004

# %%
# msnd1 vr
-78.2*(1+(-0.8)*(0.0296))
# Out:
# -76.348224

# %%
-78.2*(1+(0.2)*(0.0296))
# Out:
# -78.662944

# %%
# msnd1 d
66.9*(1+(-0.8)*(-0.45))
# Out:
# 90.98400000000001

# %%
66.9*(1+(0.2)*(-0.45))
# Out:
# 60.879000000000005

# %% [markdown]
# I

# %%
# stn 
1-(-0.45)*(-0.8)
# Out:
# 0.6399999999999999

# %%
1-(-0.45)*(0.2)
# Out:
# 1.09

# %%
1-(-0.24)*(-0.8)
# Out:
# 0.808

# %%
1-(-0.24)*(0.2)
# Out:
# 1.048

# %%
# msn 
# nmda
1+(1.04)*(-0.8)
# Out:
# 0.16799999999999993

# %%
1+(1.04)*(0.2)
# Out:
# 1.208

# %%
1+(-0.9)*(-0.8)
# Out:
# 1.7200000000000002

# %%
1+(-0.9)*(0.2)
# Out:
# 0.82

# %%
1+(0.88)*(0.2)
# Out:
# 1.176
