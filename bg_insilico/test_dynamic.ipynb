# %% [markdown]
# ### Construct simulation network (09/09)

# %%
### import packages 
from brian2 import *
from brian2.units import *
from brian2 import ms
from brian2tools import *
import matplotlib.pyplot as plt
import random
import numpy as np
import json

from simulation_runner import plot_results, run_simulation, load_params

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
- a: 
- b: 
- c:

# %%
### AdEx simulation with various parameter in Fig 4
json_file = './params/AdEx_4a.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)

# %%
### AdEx simulation with various parameter in Fig 4
json_file = './params/AdEx_4b.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)

# %%
### AdEx simulation with various parameter in Fig 4
json_file = './params/AdEx_4c.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)

# %%
from simulation_I import run_simulation, load_params, plot_results

# %%
json_file = './params_ref/FSN_1_dynamic_th.json'  

# Load parameters
params, model_name = load_params(json_file)

N = params.pop('N')['value']  
I_values = [-90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
durations = [100, 200, 300]  

# Run simulation
all_results, all_currents, total_time, injection_times = run_simulation(
    N, params, model_name, I_values, durations, injection_start_time = 200 * ms
)
# Plot results
plot_results(all_results, all_currents, I_values, total_time, injection_times, durations)
# Out:
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_s93o9hl_/flag_test.o -w
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_vejdbjoq/flag_test.o -O3
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_jyzl5qie/flag_test.o -ffast-math
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_k2e5c6ig/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_lvuxph_s/flag_test.o -march=native
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_y4kxzh0j/flag_test.o -std=c++11
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value -90. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# INFO:root:building '_cython_magic_14b3afc79fa009b61cd9c616f984a895' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_14b3afc79fa009b61cd9c616f984a895.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_14b3afc79fa009b61cd9c616f984a895.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_14b3afc79fa009b61cd9c616f984a895.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_14b3afc79fa009b61cd9c616f984a895.cpython-39-darwin.so
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value -90. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# INFO:root:building '_cython_magic_5f55a9fa647291e75cec273b38225089' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_5f55a9fa647291e75cec273b38225089.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_5f55a9fa647291e75cec273b38225089.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_5f55a9fa647291e75cec273b38225089.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_5f55a9fa647291e75cec273b38225089.cpython-39-darwin.so
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value -60. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value -60. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value -30. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value -30. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 0. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 0. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 30. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 30. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 60. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 60. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 90. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 90. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 120. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 120. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 150. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 150. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup_1', but also exists in the run namespace with the value 180. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]
# WARNING    'I' is an internal variable of group 'neurongroup', but also exists in the run namespace with the value 180. The internal variable will be used. [brian2.groups.group.Group.resolve.resolution_conflict]

# %%
json_file = './params_ref/GPe_T1_1_dynamic_th.json'  

# Load parameters
params, model_name = load_params(json_file)

N = params.pop('N')['value']  
I_values = [-90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
durations = [100, 200, 300]  

# Run simulation
all_results, all_currents, total_time, injection_times = run_simulation(
    N, params, model_name, I_values, durations, injection_start_time = 200 * ms
)
# Plot results
plot_results(all_results, all_currents, I_values, total_time, injection_times, durations)
# Out:
# INFO:root:building '_cython_magic_84e9a9bab494d46828af67fa0385c597' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_84e9a9bab494d46828af67fa0385c597.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_84e9a9bab494d46828af67fa0385c597.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_84e9a9bab494d46828af67fa0385c597.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_84e9a9bab494d46828af67fa0385c597.cpython-39-darwin.so
# INFO:root:building '_cython_magic_27eea078c7c57c44a85f96ba8fc57714' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_27eea078c7c57c44a85f96ba8fc57714.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_27eea078c7c57c44a85f96ba8fc57714.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_27eea078c7c57c44a85f96ba8fc57714.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_27eea078c7c57c44a85f96ba8fc57714.cpython-39-darwin.so

# %%
json_file = './params_ref/GPe_TA_1_dynamic_th.json'  

# Load parameters
params, model_name = load_params(json_file)

N = params.pop('N')['value']  
I_values = [-90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
durations = [100, 200, 300]  

# Run simulation
all_results, all_currents, total_time, injection_times = run_simulation(
    N, params, model_name, I_values, durations, injection_start_time = 200 * ms
)
# Plot results
plot_results(all_results, all_currents, I_values, total_time, injection_times, durations)

# %%
json_file = './params_ref/SNr_1_dynamic_th.json'  

# Load parameters
params, model_name = load_params(json_file)

N = params.pop('N')['value']  
I_values = [-90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
durations = [100, 200, 300]  

# Run simulation
all_results, all_currents, total_time, injection_times = run_simulation(
    N, params, model_name, I_values, durations, injection_start_time = 200 * ms
)
# Plot results
plot_results(all_results, all_currents, I_values, total_time, injection_times, durations)
