# %% [markdown]
# ### Construct simulation network

# %%
### import packages 
from brian2 import *
from brian2.units import *
from brian2 import ms
from brian2tools import *
import matplotlib.pyplot as plt
import random
import numpy as np
import json

from simulation_runner import plot_results, run_simulation, load_params

# %%
### AdEx simulation with various parameter in Fig 4
json_file = './params/AdEx_4a.json' 

# load parameters
params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

# simulation 
results = run_simulation(N, params, model_name)

# visualization
plot_results(results)
# Out:
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_cn_p2uej/flag_test.o -w
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_tskun1x2/flag_test.o -O3
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_aeuqy8id/flag_test.o -ffast-math
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_zxvgeajt/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_291dpfvw/flag_test.o -march=native
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders/tj
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T
# INFO:root:creating /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -c /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/flag_test.cpp -o /var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/var/folders/tj/9vhjqp2n63ng9609fgfkf_dc0000gn/T/brian_flag_test_39k9w6pc/flag_test.o -std=c++11

# %% [markdown]
# ### Noise
# - Given the noisy nature of neuronal activity in vivo, neurons receive noisy time varying inputs
# - https://brian2.readthedocs.io/en/stable/user/models.html

# %%
### import packages 
from brian2 import *
from brian2.units import *
from brian2 import ms
from brian2 import profiling_summary
from brian2tools import *
import matplotlib.pyplot as plt
import random
import numpy as np
import json

from simulation_I_noise import run_simulation, load_params, plot_results

# %%
### Inject normal distribution white noise current 

mu_noise = 100*pA
sigma_noise = 15*pA
E_L = -85.4*mV
g_L = 6.46*nS
C = 157*pF

def run_sim(dt):
    defaultclock.dt = dt
    group = NeuronGroup(1,
                         '''dv/dt = (-g_L*(v - E_L) + I_noise)/C : volt
                            I_noise = mu_noise + sigma_noise*randn() : amp (constant over dt)''',
                        method='exact')
    group.v = E_L
    mon = StateMonitor(group, ['v', 'I_noise'], record=0)
    net = Network(group, mon)
    net.run(500 * ms, profile=True)

    return mon.t[:], mon.v[0], mon.I_noise[0], net

t1, v1, I_noise1, net1 = run_sim(0.5 * ms)
t2, v2, I_noise2, net2 = run_sim(0.01 * ms)

# Plot the results
fig, axs = plt.subplots(4, 2, sharey='row',
                        gridspec_kw={'width_ratios': [3, 1]},
                        constrained_layout=True)

axs[0, 0].plot(t1 / ms, I_noise1 / pA)
axs[0, 0].set_ylabel('I_noise (pA)')
axs[0, 1].hist(I_noise1 / pA, bins=np.arange(0, 100, 5), orientation='horizontal')
axs[1, 0].plot(t1 / ms, v1 / mV)
axs[1, 0].set_ylim(-90, -65)
axs[1, 0].set_ylabel('v (mV)')
axs[1, 1].axis('off')

axs[2, 0].plot(t2 / ms, I_noise2 / pA)
axs[2, 0].set_ylabel('I_noise (pA)')
axs[2, 1].hist(I_noise2 / nA, bins=np.arange(0, 100, 5), orientation='horizontal')
axs[3, 0].plot(t2 / ms, v2 / mV)
axs[3, 0].set_ylim(-90, -65)
axs[3, 0].set_ylabel('v (mV)')
axs[3, 1].axis('off')
axs[3, 0].set_xlabel('t (ms)')

plt.show()

# Display the profiling summary
profiling_summary(net1, show=5)
# Out:
# INFO:root:building '_cython_magic_09e8aa1b942317b632013cf418414b6d' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_09e8aa1b942317b632013cf418414b6d.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_09e8aa1b942317b632013cf418414b6d.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_09e8aa1b942317b632013cf418414b6d.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_09e8aa1b942317b632013cf418414b6d.cpython-39-darwin.so
# Profiling summary
# =================
# statemonitor_2                        4.19 ms    58.81 %
# neurongroup_1_subexpression_update    1.49 ms    20.90 %
# neurongroup_1_stateupdater            1.16 ms    16.36 %
# neurongroup_1                         0.28 ms     3.93 %

# %%
### Inject normal distribution white noise current 

mu_noise = 100*pA
sigma_noise = 300*pA
E_L = -85.4*mV
g_L = 6.46*nS
C = 157*pF

def run_sim(dt):
    defaultclock.dt = dt
    group = NeuronGroup(1,
                         '''dv/dt = (-g_L*(v - E_L) + I_noise)/C : volt
                            I_noise = mu_noise + sigma_noise*randn() : amp (constant over dt)''',
                        method='exact')
    group.v = E_L
    mon = StateMonitor(group, ['v', 'I_noise'], record=0)

    run(500*ms)
    return mon.t[:], mon.v[0], mon.I_noise[0]

t1, v1, I_noise1 = run_sim(0.5*ms)
t2, v2, I_noise2 = run_sim(0.01*ms)

fig, axs = plt.subplots(4, 2, sharey='row',
                       gridspec_kw={'width_ratios': [3, 1]},
                       constrained_layout=True)

axs[0, 0].plot(t1/ms, I_noise1/pA)
axs[0, 0].set_ylabel('I_noise (pA)')
axs[0, 1].hist(I_noise1/pA, bins=np.arange(-1000, 1000, 100), orientation='horizontal')
axs[1, 0].plot(t1/ms, v1/mV)
axs[1, 0].set_ylim(-90, -50)
axs[1, 0].set_ylabel('v (mV)')
axs[1, 1].axis('off')

axs[2, 0].plot(t2/ms, I_noise2/pA)
axs[2, 0].set_ylabel('I_noise (pA)')
axs[2, 1].hist(I_noise2/pA, bins=np.arange(-1000, 1000, 100), orientation='horizontal')
axs[3, 0].plot(t2/ms, v2/mV)
axs[3, 0].set_ylim(-90, -65)
axs[3, 0].set_ylabel('v (mV)')
axs[3, 1].axis('off')
axs[3, 0].set_xlabel('t (ms)')

plt.show()
# Out:
# INFO:root:building '_cython_magic_bdd257c4d3a7af6cd5a71e020a4a07bd' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_bdd257c4d3a7af6cd5a71e020a4a07bd.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_bdd257c4d3a7af6cd5a71e020a4a07bd.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_bdd257c4d3a7af6cd5a71e020a4a07bd.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_bdd257c4d3a7af6cd5a71e020a4a07bd.cpython-39-darwin.so

# %%
# GWN with LIF model 
from simulation_runner import plot_results, run_simulation_noise, load_params

json_file = './params/LIF_noise.json'  

# Load parameters
params, model_name = load_params(json_file)

N = params.pop('N')['value']  

# simulation 
results, noise_data = run_simulation_noise(N, params, model_name)

# visualization
plot_results(results)
# Out:
# warning: /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_2a8a67cba80fa7208b90946a777d9510.pyx:109:24: local variable '_source_xi' referenced before assignment
# INFO:root:building '_cython_magic_2a8a67cba80fa7208b90946a777d9510' extension
# INFO:root:arm64-apple-darwin20.0.0-clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/brain/include -arch arm64 -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/numpy/core/include -I/opt/anaconda3/envs/brain/lib/python3.9/site-packages/brian2/synapses -I/opt/anaconda3/envs/brain/include/python3.9 -c /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_2a8a67cba80fa7208b90946a777d9510.cpp -o /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_2a8a67cba80fa7208b90946a777d9510.o -w -O3 -ffast-math -fno-finite-math-only -march=native -std=c++11
# INFO:root:arm64-apple-darwin20.0.0-clang++ -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-pie -Wl,-rpath,/opt/anaconda3/envs/brain/lib -L/opt/anaconda3/envs/brain/lib -ftree-vectorize -fPIC -fstack-protector-strong -O2 -pipe -fPIE -isystem /opt/anaconda3/envs/brain/include -D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/brain/include /Users/tacolab4/Library/Caches/cython/brian_extensions/Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_2a8a67cba80fa7208b90946a777d9510.o -L/opt/anaconda3/envs/brain/lib -Wl,-rpath,/opt/anaconda3/envs/brain/lib -o /Users/tacolab4/Library/Caches/cython/brian_extensions/_cython_magic_2a8a67cba80fa7208b90946a777d9510.cpython-39-darwin.so

# %%
# Gaussian white noise (GWN) current 
from simulation_I_noise import plot_results, run_simulation, load_params

json_file = './params/LIF_noise.json'  

params, model_name = load_params(json_file)

N = params.pop('N')['value']  
I_values = [-90, -60, -30, 0, 30, 60, 90, 120, 150, 180]
durations = [100, 200, 300]  

all_results, all_currents, total_time, injection_times = run_simulation(
    N, params, model_name, I_values, durations, injection_start_time = 200 * ms
)

plot_results(all_results, all_currents, I_values, total_time, injection_times, durations)

# %% [markdown]
# ### Synapse Connection

# %%
### GPe simulation
from simulation_runner import plot_results, run_simulation, load_params

json_file = './params_ref/GPe_TA_1.json' 

params, model_name = load_params(json_file)
N = params.pop('N')['value'] 

results = run_simulation(N, params, model_name)

plot_results(results)

# %%
### Spontaneuous result without I
from simulation_runner_syn import run_simulation_without_input, plot_results_pre_post, plot_results_with_weight_matrix, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_without_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_results_with_weight_matrix(results, N_GPe, N_STN)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.17s). [brian2.stateupdaters.base.method_choice]

# %%
### Spontaneuous result with current I (200ms ~ 500ms)
from simulation_runner_syn import run_simulation_with_input, plot_results_pre_post, plot_connectivity
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses_1', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]

# %%
### adjust gap between vt, vr
from simulation_runner_syn import run_simulation_with_input, plot_results_pre_post, plot_raster
from brian2 import * 

gpe_params_file = './params_ref/GPe_T1_1_temp.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)

# %%
### Spontaneuous result with current I (ref 3)

gpe_params_file = './params_ref/GPe_T1_3.json'
stn_params_file = './params_ref/STN_3.json'

synapse_params = {
    'g0': 0.08*nS,
    'tau_syn': 8*ms,
    'E_GABA': -84*mV
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN"
)

plot_results_pre_post(results)
plot_raster(results)

# %%
from simulation_runner_syn import plot_connectivity
plot_connectivity(results['synapse'], N_GPe, N_STN, title='GPe to STN Synaptic Connectivity')

# %% [markdown]
# ### Striatum - GPe - STN inhibitory (GABA)

# %%
### Result with inh/ext input 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    # EXT - GPe
    'striatum_g0': 0.5 * nS,
    'striatum_ampa_E_rev': 0 * mV,
    'striatum_ampa_tau_syn': 5 * ms,

    # GPe - STN
    'g0': 1*nS,
    'ampa_tau_syn': 8*ms,  # ampa (Hanson & Dieter Jaeger 2002)
    'ampa_E_rev': -84*mV
  
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses_2', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.01s). [brian2.stateupdaters.base.method_choice]

# %%
### Result with inh/ext input 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_1.json'
stn_params_file = './params_ref/STN_1.json'

synapse_params = {
    # EXT - GPe
    'striatum_g0': 0.5 * nS,
    'striatum_ampa_E_rev': 0 * mV,
    'striatum_ampa_tau_syn': 5 * ms,

    # GPe - STN
    'g0': 1*nS,
    'ampa_tau_syn': 8*ms,  # ampa (Hanson & Dieter Jaeger 2002)
    'ampa_E_rev': -84*mV
  
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)
# Out:
# INFO       No numerical integration method specified for group 'synapses_1', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
# INFO       No numerical integration method specified for group 'synapses_3', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]

# %%
### Result with inh/ext input 
from simulation_runner_syn import run_simulation_with_inh_ext_input, plot_results_pre_post, plot_raster
from brian2 import *

gpe_params_file = './params_ref/GPe_T1_3.json' # increase I to 300pA
stn_params_file = './params_ref/STN_3.json'

synapse_params = {
    # EXT - GPe
    'striatum_g0': 0.5 * nS,
    'striatum_ampa_E_rev': 0 * mV,
    'striatum_ampa_tau_syn': 5 * ms,

    # GPe - STN
    'g0': 1*nS,
    'ampa_tau_syn': 8*ms,  # ampa (Hanson & Dieter Jaeger 2002)
    'ampa_E_rev': -84*mV
  
}

N_GPe = 30 
N_STN = 30 

results = run_simulation_with_inh_ext_input(
    N_GPe,
    N_STN,
    gpe_params_file,
    stn_params_file,
    synapse_params,
    'GPe', 
    'STN', 
    "GPe_STN_inh_ext"
)

plot_results_pre_post(results)
plot_raster(results)

# %% [markdown]
# - STDP: normal vs dopamine
# - https://brian2.readthedocs.io/en/stable/examples/frompapers.Izhikevich_2007.html
#
# - AdEX parameter list
# - https://brian2.readthedocs.io/en/stable/examples/frompapers.Naud_et_al_2008_adex_firing_patterns.html
# - delay 파라미터: 논문3 table1 참고
